# %%
import pandas as pd

# %%
df = pd.read_excel(r'SQL_Result_Dataset\CovidKeyFactors.xlsx')

# %%
df
# Out:
#            location  TotalDeathPercentage  TotalVaccinationPercentage  \
# 0             Yemen                  18.1                        2.67
# 1             Sudan                   7.9                        1.77
# 2             Syria                   5.5                        4.42
# 3           Somalia                   5.0                        5.48
# 4              Peru                   4.9                       29.37
# ..              ...                   ...                         ...
# 238  Western Sahara                   NaN                         NaN
# 239         England                   NaN                      176.61
# 240         Vatican                   NaN                         NaN
# 241    Saint Helena                   NaN                      146.12
# 242           Macao                   NaN                      143.77
#
#      ExtremePovertyPercentage  GDPPerCapita  Aged70OverPercentage  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 243 entries, 0 to 242
# Data columns (total 9 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   location                    243 non-null    object
#  1   TotalDeathPercentage        226 non-null    float64
#  2   TotalVaccinationPercentage  223 non-null    float64
#  3   ExtremePovertyPercentage    125 non-null    float64
#  4   GDPPerCapita                195 non-null    float64
#  5   Aged70OverPercentage        198 non-null    float64
#  6   HospitalbedsPer1000         172 non-null    float64
#  7   CardiovascDeathPer100000    195 non-null    float64
#  8   DiabetesPrevalence          205 non-null    float64
# dtypes: float64(8), object(1)
# memory usage: 17.2+ KB

# %%
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder
# %matplotlib inline

# %%
# Create a heatmap to visualize the relationships between the numeric variables

# Exclude the non-numeric column (the 'location' cloumn in this case)
numeric_df = df.select_dtypes(include=['int', 'float'])

# Create the heatmap
plt.figure(figsize=(10, 6))
sns.heatmap(numeric_df.corr(), annot=True, cmap='coolwarm', fmt=".2f", linewidths=0.5)
plt.title('Correlation Heatmap')
# Out:
# Text(0.5, 1.0, 'Correlation Heatmap')

# %% [markdown]
# ### Interpretations of the result
#
# 1. TotalDeathPercentage vs. TotalVaccinationPercentage:
# - Correlation coefficient: -0.24
# - Interpretation: There is a weak negative correlation between the percentage of total deaths and the percentage of total vaccinations. This suggests that countries with higher vaccination percentages tend to have slightly lower death percentages, and vice versa.
#
# 2. TotalDeathPercentage vs. ExtremePovertyPercentage:
# - Correlation coefficient: 0.09
# - Interpretation: There is a weak positive correlation between the percentage of total deaths and the percentage of extreme poverty. This suggests that countries with higher percentages of extreme poverty tend to have slightly higher death percentages, and vice versa.
#
# 3. TotalDeathPercentage vs. GDPPerCapita:
# - Correlation coefficient: -0.30
# - Interpretation: There is a moderate negative correlation between the percentage of total deaths and the GDP per capita. This suggests that countries with higher GDP per capita tend to have slightly lower death percentages, and vice versa.
#
# 4. TotalDeathPercentage vs. Aged70OverPercentage:
# - Correlation coefficient: -0.22
# - Interpretation: There is a weak negative correlation between the percentage of total deaths and the percentage of population aged 70 and over. This suggests that countries with higher proportions of elderly populations tend to have slightly lower death percentages, and vice versa.
#
# 5. TotalDeathPercentage vs. HospitalbedsPer1000:
# - Correlation coefficient: -0.25
# - Interpretation: There is a weak negative correlation between the percentage of total deaths and the number of hospital beds per 1000 people. This suggests that countries with more hospital beds per capita tend to have slightly lower death percentages, and vice versa.
#
# 6. TotalDeathPercentage vs. CardiovascDeathPer100000:
# - Correlation coefficient: 0.26
# - Interpretation: There is a weak positive correlation between the percentage of total deaths and the cardiovascular death rate per 100,000 people. This suggests that countries with higher cardiovascular death rates tend to have slightly higher death percentages, and vice versa.
#
# 7. TotalDeathPercentage vs. DiabetesPrevalence:
# - Correlation coefficient: -0.14
# - Interpretation: There is a weak negative correlation between the percentage of total deaths and the prevalence of diabetes. This suggests that countries with higher diabetes prevalence rates tend to have slightly lower death percentages, and vice versa.
#
# The above interpretations provide insights into the relationships between the variables based on the correlation coefficients. The correlation does not imply causation, and other factors may influence the observed relationships.
